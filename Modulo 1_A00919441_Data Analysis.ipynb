# %%
#se importan todas las librerías a utilizar para este ejercicio

import piplite
import micropip
await piplite.install(['pandas'])
await piplite.install(['matplotlib'])
await piplite.install(['scipy'])
await piplite.install(['seaborn'])
await micropip.install(['ipywidgets'],keep_going=True)
8await micropip.install(['tqdm'],keep_going=True)
import pandas as pd
import numpy as np

# %%
#se utiliza el comando read_csv para leer este archivo
#en caso de ser otro tipo de archivo se coloca la palabra del tipo de archivo en vez de csv, Ej: read_excel, read_jstor, read_sql
df=pd.read_csv("mexico_covid19.csv")

# %%
df.head() #se visualizan los primeros 5 filas del archivo
# Out:
#       id FECHA_ARCHIVO ID_REGISTRO  ENTIDAD_UM  ENTIDAD_RES  RESULTADO  DELAY  \
# 0   9269    12/04/2020      00011f          25           25          2      0
# 1  33333    12/04/2020      00014e          14           14          2      0
# 2  35483    12/04/2020         153           8            8          1      0
# 3   7062    12/04/2020      0001b6           9           15          1      0
# 4  23745    12/04/2020      0001c1           9            9          2      0
#
#    ENTIDAD_REGISTRO           ENTIDAD ABR_ENT  ... OTRA_COM  CARDIOVASCULAR  \
# 0                25           Sinaloa      SL  ...        2               2
# 1                14           Jalisco      JC  ...        2               2
# 2                 8         Chihuahua      CH  ...        2               2
# 3                 9  Ciudad de Mexico      DF  ...        2               2
# 4                 9  Ciudad de Mexico      DF  ...        2               2
#
# ...

# %%
df.tail() #se visualizan los primeros 5 filas del archivo
# Out:
#        id FECHA_ARCHIVO ID_REGISTRO  ENTIDAD_UM  ENTIDAD_RES  RESULTADO  \
# 52  22013    12/04/2020      0010d5           9            9          2
# 53  20529    12/04/2020    1.00E+09           9            9          2
# 54  11377    12/04/2020      00111a          14           14          2
# 55  35045    12/04/2020        1134           9            9          2
# 56   8114    12/04/2020        1144           9            9          2
#
#     DELAY  ENTIDAD_REGISTRO           ENTIDAD ABR_ENT  ... OTRA_COM  \
# 52      0                 9  Ciudad de Mexico      DF  ...        2
# 53      0                 9  Ciudad de Mexico      DF  ...        2
# 54      0                14           Jalisco      JC  ...        2
# 55      0                 9  Ciudad de Mexico      DF  ...        2
# 56      0                 9  Ciudad de Mexico      DF  ...        2
#
#     CARDIOVASCULAR  OBESIDAD  RENAL_CRONICA  TABAQUISMO  OTRO_CASO  MIGRANTE  \
# ...

# %%
#se revisa que tipo de información contiene cada columna
df.dtypes
# Out:
# id                      int64
# FECHA_ARCHIVO          object
# ID_REGISTRO            object
# ENTIDAD_UM              int64
# ENTIDAD_RES             int64
# RESULTADO               int64
# DELAY                   int64
# ENTIDAD_REGISTRO        int64
# ENTIDAD                object
# ABR_ENT                object
# FECHA_ACTUALIZACION    object
# ORIGEN                  int64
# SECTOR                  int64
# SEXO                    int64
# ENTIDAD_NAC             int64
# MUNICIPIO_RES           int64
# TIPO_PACIENTE           int64
# FECHA_INGRESO          object
# FECHA_SINTOMAS         object
# FECHA_DEF              object
# INTUBADO                int64
# NEUMONIA                int64
# EDAD                    int64
# NACIONALIDAD            int64
# EMBARAZO                int64
# HABLA_LENGUA_INDIG      int64
# DIABETES                int64
# EPOC                    int64
# ASMA                    int64
# INMUSUPR                int64
# HIPERTENSION            int64
# ...

# %%
#nombre de las columnas
df.columns
# Out:
# Index(['id', 'FECHA_ARCHIVO', 'ID_REGISTRO', 'ENTIDAD_UM', 'ENTIDAD_RES',
#        'RESULTADO', 'DELAY', 'ENTIDAD_REGISTRO', 'ENTIDAD', 'ABR_ENT',
#        'FECHA_ACTUALIZACION', 'ORIGEN', 'SECTOR', 'SEXO', 'ENTIDAD_NAC',
#        'MUNICIPIO_RES', 'TIPO_PACIENTE', 'FECHA_INGRESO', 'FECHA_SINTOMAS',
#        'FECHA_DEF', 'INTUBADO', 'NEUMONIA', 'EDAD', 'NACIONALIDAD', 'EMBARAZO',
#        'HABLA_LENGUA_INDIG', 'DIABETES', 'EPOC', 'ASMA', 'INMUSUPR',
#        'HIPERTENSION', 'OTRA_COM', 'CARDIOVASCULAR', 'OBESIDAD',
#        'RENAL_CRONICA', 'TABAQUISMO', 'OTRO_CASO', 'MIGRANTE',
#        'PAIS_NACIONALIDAD', 'PAIS_ORIGEN', 'UCI'],
#       dtype='object')

# %%
df.describe()     #estadísticas de la base de datos
# Out:
#                  id  ENTIDAD_UM  ENTIDAD_RES  RESULTADO  DELAY  \
# count     57.000000   57.000000    57.000000  57.000000   57.0
# mean   17854.140351   14.947368    15.052632   1.842105    0.0
# std    10982.442552    8.775821     8.739118   0.367884    0.0
# min      444.000000    2.000000     2.000000   1.000000    0.0
# 25%     7217.000000    9.000000     9.000000   2.000000    0.0
# 50%    17334.000000   14.000000    14.000000   2.000000    0.0
# 75%    28767.000000   19.000000    19.000000   2.000000    0.0
# max    35483.000000   32.000000    32.000000   2.000000    0.0
#
#        ENTIDAD_REGISTRO     ORIGEN     SECTOR       SEXO  ENTIDAD_NAC  ...  \
# count         57.000000  57.000000  57.000000  57.000000    57.000000  ...
# mean          14.947368   1.561404   7.631579   1.438596    38.877193  ...
# std            8.775821   0.500626   3.921696   0.500626    35.434583  ...
# min            2.000000   1.000000   3.000000   1.000000     2.000000  ...
# ...

# %%
df[["id", "DELAY"]].describe()  #se puede describir la información de las columnas deseadas, colocando el nombre de las columnas a elegir en corchete previo al comando describe
# Out:
#                  id  DELAY
# count     57.000000   57.0
# mean   17854.140351    0.0
# std    10982.442552    0.0
# min      444.000000    0.0
# 25%     7217.000000    0.0
# 50%    17334.000000    0.0
# 75%    28767.000000    0.0
# max    35483.000000    0.0

# %%
df.to_csv("mexico_covid19.csv", index=False) #guardar base de datos con el comando to_csv

# %%
df.info   #información general de la base de datos
# Out:
# <bound method DataFrame.info of        id FECHA_ARCHIVO ID_REGISTRO  ENTIDAD_UM  ENTIDAD_RES  RESULTADO  \
# 0    9269    12/04/2020      00011f          25           25          2
# 1   33333    12/04/2020      00014e          14           14          2
# 2   35483    12/04/2020         153           8            8          1
# 3    7062    12/04/2020      0001b6           9           15          1
# 4   23745    12/04/2020      0001c1           9            9          2
# 5    5019    12/04/2020      0001d2          19           19          2
# 6   30173    12/04/2020    1.00E+07          17           17          2
# 7   26574    12/04/2020      00022b          27           27          2
# 8    4265    12/04/2020         275          19           19          2
# 9   25444    12/04/2020    2.00E+07          15           15          2
# 10  12204    12/04/2020      0002ec           9            9          2
# 11   3321    12/04/2020      0002f5           9            9          2
# ...

# %%
df.dropna()
# Out:
#        id FECHA_ARCHIVO ID_REGISTRO  ENTIDAD_UM  ENTIDAD_RES  RESULTADO  \
# 0    9269    12/04/2020      00011f          25           25          2
# 1   33333    12/04/2020      00014e          14           14          2
# 2   35483    12/04/2020         153           8            8          1
# 3    7062    12/04/2020      0001b6           9           15          1
# 4   23745    12/04/2020      0001c1           9            9          2
# 5    5019    12/04/2020      0001d2          19           19          2
# 6   30173    12/04/2020    1.00E+07          17           17          2
# 7   26574    12/04/2020      00022b          27           27          2
# 8    4265    12/04/2020         275          19           19          2
# 9   25444    12/04/2020    2.00E+07          15           15          2
# 10  12204    12/04/2020      0002ec           9            9          2
# 11   3321    12/04/2020      0002f5           9            9          2
# ...
