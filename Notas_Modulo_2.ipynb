# %% [raw]
# David Winterman
# A00919441

# %% [raw]
# El pre procesamiento de datos sirve para transformar la base de datos original ad hoc a una base que funcione para analizar la informaciónd e acuerdo a los objetivos trazados.

# %%
import pandas as pd
import matplotlib as plot

# %% [raw]
# Se utiliza el ejemplo del laboratorio de IBM

# %%
df = pd.read_csv("auto.csv", names=headers)

# %%
headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %% [raw]
# El primer paso es encontrar la información faltante la cual puede ser representada como "?", "NaN" o la celda vacia.

# %%
import numpy as np

# %%
df.replace("?",np.nan, inplace=True)

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3               NaN  alfa-romero       gas        std          two
# 1          3               NaN  alfa-romero       gas        std          two
# 2          1               NaN  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
md=df.isnull() #detectamos cuantos datos faltantes hay
md.head()   #el True es que si hay datos faltantes, el False es de que no
# Out:
#    symboling  normalized-losses   make  fuel-type  aspiration  num-of-doors  \
# 0      False               True  False      False       False         False
# 1      False               True  False      False       False         False
# 2      False               True  False      False       False         False
# 3      False              False  False      False       False         False
# 4      False              False  False      False       False         False
#
#    body-style  drive-wheels  engine-location  wheel-base  ...  engine-size  \
# 0       False         False            False       False  ...        False
# 1       False         False            False       False  ...        False
# 2       False         False            False       False  ...        False
# 3       False         False            False       False  ...        False
# 4       False         False            False       False  ...        False
#
# ...

# %%
md2=df.notnull() #otro metodo ppara verificqr datos faltantes
md2
# Out:
#      symboling  normalized-losses  make  fuel-type  aspiration  num-of-doors  \
# 0         True              False  True       True        True          True
# 1         True              False  True       True        True          True
# 2         True              False  True       True        True          True
# 3         True               True  True       True        True          True
# 4         True               True  True       True        True          True
# ..         ...                ...   ...        ...         ...           ...
# 200       True               True  True       True        True          True
# 201       True               True  True       True        True          True
# 202       True               True  True       True        True          True
# 203       True               True  True       True        True          True
# 204       True               True  True       True        True          True
#
# ...

# %%
md.value_counts()
# Out:
# symboling  normalized-losses  make   fuel-type  aspiration  num-of-doors  body-style  drive-wheels  engine-location  wheel-base  length  width  height  curb-weight  engine-type  num-of-cylinders  engine-size  fuel-system  bore   stroke  compression-ratio  horsepower  peak-rpm  city-mpg  highway-mpg  price
# False      False              False  False      False       False         False       False         False            False       False   False  False   False        False        False             False        False        False  False   False              False       False     False     False        False    159
#            True               False  False      False       False         False       False         False            False       False   False  False   False        False        False             False        False        False  False   False              False       False     False     False        False     34
# ...

# %%
para tratar con datos faltantes, estos ueden ser eliminados con el comando .drpona o pueden ser remplazados por el promedio de los valores de cada columna donde pertenecen

# %%
mean=df["stroke"].astype("float").mean()
df.replace(np.nan,mean, inplace=True)
df

#se obtiene la media para modificar los datos faltantes con el promedio de los datos de la columnq seleccionada
#se utiliza el comando astype para modificqr el tipo de datos de la columna, en este caso de un str a un float
#se utiliza el comando replace para cambiar todos los nan por la media
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3          3.255423  alfa-romero       gas        std
# 1            3          3.255423  alfa-romero       gas        std
# 2            1          3.255423  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
mean #valor promedio de la columna stroke
# Out:
# 3.255422885572139

# %%
df["num-of-doors"].value_counts() #contabiliza la cantidad de valores por cada concepto en una columna
# Out:
# four                 114
# two                   89
# 3.255422885572139      2
# Name: num-of-doors, dtype: int64

# %%
df["num-of-doors"].value_counts().idxmax() #el comando idxmax te da el atributo de la columna con mas repeticiones
# Out:
# 'four'

# %%
df.dropna(subset=["price"],axis=0)  #se utiliza el comando dropna para eliminar las filas que no tengan valor
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3          3.255423  alfa-romero       gas        std
# 1            3          3.255423  alfa-romero       gas        std
# 2            1          3.255423  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
df.dtypes  #te da el tipo de valor que contiene cada columna
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
df["highway-mpg"] = 235/df["highway-mpg"]

df.rename(columns={'highway-mpg':'highway-L/100km'}, inplace=True)

df.head()

#este es un ejemplo de standariación donde hacemos que todas las columnas se estandaricen a un mismo tipo de medida para hacer analisis correctos
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3          3.255423  alfa-romero       gas        std          two
# 1          3          3.255423  alfa-romero       gas        std          two
# 2          1          3.255423  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %% [raw]
# Normalizar una base de datos es colocar valores entre 0 y 1 a los atributos para darle sentido a los datos
#
# Acontinuacio´n se presenta un ejemplo

# %%
df['length'] = df['length']/df['length'].max()
df['width'] = df['width']/df['width'].max()
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3          3.255423  alfa-romero       gas        std          two
# 1          3          3.255423  alfa-romero       gas        std          two
# 2          1          3.255423  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %% [raw]
# El proceso de Binning ayuda a convertir unos datos continuos en discretos, es decir, podemos agrupar una cantidad de datos en diferentes categorias.
#
# A continuación un ejemplo

# %%
df["horsepower"]=df["horsepower"].astype(int, copy=True)

# %%
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot
plt.pyplot.hist(df["horsepower"])


plt.pyplot.xlabel("horsepower")
plt.pyplot.ylabel("count")
plt.pyplot.title("horsepower bins")
# Out:
# Text(0.5, 1.0, 'horsepower bins')

# %%
bins = np.linspace(min(df["horsepower"]), max(df["horsepower"]), 4)
bins
# Out:
# array([  3.,  98., 193., 288.])

# %%
group_names = ['Low', 'Medium', 'High']

# %%
df['horsepower-binned'] = pd.cut(df['horsepower'], bins, labels=group_names, include_lowest=True )
df[['horsepower','horsepower-binned']].head(20)
# Out:
#     horsepower horsepower-binned
# 0          111            Medium
# 1          111            Medium
# 2          154            Medium
# 3          102            Medium
# 4          115            Medium
# 5          110            Medium
# 6          110            Medium
# 7          110            Medium
# 8          140            Medium
# 9          160            Medium
# 10         101            Medium
# 11         101            Medium
# 12         121            Medium
# 13         121            Medium
# 14         121            Medium
# 15         182            Medium
# 16         182            Medium
# 17         182            Medium
# 18          48               Low
# 19          70               Low

# %%
df["horsepower-binned"].value_counts()
# Out:
# Low       111
# Medium     88
# High        6
# Name: horsepower-binned, dtype: int64

# %%
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot
pyplot.bar(group_names, df["horsepower-binned"].value_counts())

# set x/y labels and plot title
plt.pyplot.xlabel("horsepower")
plt.pyplot.ylabel("count")
plt.pyplot.title("horsepower bins")
# Out:
# Text(0.5, 1.0, 'horsepower bins')

# %% [raw]
# Las variables dummys son aquellas que utilizan un numero para identificar o rtiquetar una categoría pero en si el número no tiene ingerencia sobre el análisis.

# %%
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-L/100km', 'price', 'horsepower-binned'],
#       dtype='object')

# %%
dummy_variable_1 = pd.get_dummies(df["fuel-type"])
dummy_variable_1.head()

#se utiliza el comando get_dummies para crear una variable dummy
# Out:
#    diesel  gas
# 0       0    1
# 1       0    1
# 2       0    1
# 3       0    1
# 4       0    1

# %%
#con el comando rename modificamos el nombre de las columnas
dummy_variable_1.rename(columns={'gas':'fuel-type-gas', 'diesel':'fuel-type-diesel'}, inplace=True)
dummy_variable_1.head()
# Out:
#    fuel-type-diesel  fuel-type-gas
# 0                 0              1
# 1                 0              1
# 2                 0              1
# 3                 0              1
# 4                 0              1
