# %% [raw]
# Notas del modulo 3

# %%
import piplite
await piplite.install(['pandas'])
await piplite.install(['matplotlib'])
await piplite.install(['scipy'])
await piplite.install(['seaborn'])
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %matplotlib inline

# %%
headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]

# %%
df=pd.read_csv("auto.csv", names=headers)
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
df.dropna()
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %% [raw]
# Con el comando dtype() podemos visualizar que tipo de datos son cada columna del dataframe

# %%
print (df.dtypes)
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %% [raw]
# Si se quiere analizar lo mismo pero con unas columnas en especifico solamente en corchetes se especifica el nombre o nombres de las columnas a analizar

# %%
df["symboling"].dtypes
# Out:
# dtype('int64')

# %% [raw]
# Para calcular la correlación se utiliza el comando .corr

# %%
df.corr()
# Out:
#                    symboling  wheel-base    length     width    height  \
# symboling           1.000000   -0.531954 -0.357612 -0.232919 -0.541038
# wheel-base         -0.531954    1.000000  0.874587  0.795144  0.589435
# length             -0.357612    0.874587  1.000000  0.841118  0.491029
# width              -0.232919    0.795144  0.841118  1.000000  0.279210
# height             -0.541038    0.589435  0.491029  0.279210  1.000000
# curb-weight        -0.227691    0.776386  0.877728  0.867032  0.295572
# engine-size        -0.105790    0.569329  0.683360  0.735433  0.067149
# compression-ratio  -0.178515    0.249786  0.158414  0.181129  0.261214
# city-mpg           -0.035823   -0.470414 -0.670909 -0.642704 -0.048640
# highway-mpg         0.034606   -0.544082 -0.704662 -0.677218 -0.107358
#
#                    curb-weight  engine-size  compression-ratio  city-mpg  \
# symboling            -0.227691    -0.105790          -0.178515 -0.035823
# ...

# %%
df[["engine-size", "length"]].corr()   #otro ejemplo
# Out:
#              engine-size   length
# engine-size      1.00000  0.68336
# length           0.68336  1.00000

# %% [raw]
# Una scatter plot es un diagrama de punto que te da a conocer de manera grafica la correlación entre dos variables

# %%
sns.regplot(x="engine-size", y="length", data=df)


#aqui podemos notar que la correlación es positiva
# Out:
# <AxesSubplot:xlabel='engine-size', ylabel='length'>

# %% [raw]
# Con el comando describe podemos analizar los estadísticos principales del data frame los cuales luego utilizaremos para hacer un diagrama de caja

# %%
df.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   205.000000   205.000000         205.000000  205.000000   205.000000
# mean   2555.565854   126.907317          10.142537   25.219512    30.751220
# std     520.680204    41.642693           3.972040    6.542142     6.886443
# ...

# %%
sns.boxplot(x="engine-size", y="length", data=df)
# Out:
# <AxesSubplot:xlabel='engine-size', ylabel='length'>

# %% [raw]
# Tambien puedes describir un tipo de información aclarando cual es el que qquieres analizar si int, floats, object,etc

# %%
df.describe(include=['object'])
# Out:
#        normalized-losses    make fuel-type aspiration num-of-doors body-style  \
# count                205     205       205        205          205        205
# unique                52      22         2          2            3          5
# top                    ?  toyota       gas        std         four      sedan
# freq                  41      32       185        168          114         96
#
#        drive-wheels engine-location engine-type num-of-cylinders fuel-system  \
# count           205             205         205              205         205
# unique            3               2           7                7           8
# top             fwd           front         ohc             four        mpfi
# freq            120             202         148              159          94
#
#         bore stroke horsepower peak-rpm price
# count    205    205        205      205   205
# unique    39     37         60       24   187
# top     3.62   3.40         68     5500     ?
# ...

# %% [raw]
# Con el comando .value_counts() se puede aanalizar cuantos valores y de que tipo hay en cada columna

# %%
df["drive-wheels"].value_counts()
# Out:
# fwd    120
# rwd     76
# 4wd      9
# Name: drive-wheels, dtype: int64

# %% [raw]
# Agrupar es otra función que da python y tiene varios estilos

# %%
df["drive-wheels"].unique()   #el comando unique te agrupa los valores unicos que contiene una columna o data frame
# Out:
# array(['rwd', 'fwd', '4wd'], dtype=object)

# %%
df_group_one = df[['drive-wheels','body-style','length']]

# %%
df_group_one = df_group_one.groupby(['drive-wheels'],as_index=False).mean()
df_group_one

#con el comando groupby y mean logramos agrupar los valores de la columna drive wheel en valores únicos y con el promedio de la columna length
# Out:
#   drive-wheels      length
# 0          4wd  171.411111
# 1          fwd  168.780000
# 2          rwd  182.681579

# %%
grouped_pivot = df_group_one.pivot(index='drive-wheels',columns='length')
grouped_pivot    #la opción pivot nos da una manera dferente de acomodar la información, en una tabla dinámica
# Out:
# Empty DataFrame
# Columns: []
# Index: [4wd, fwd, rwd]

# %%
from scipy import stats

# %%
pearson_coef, p_value = stats.pearsonr(df['wheel-base'], df['length'])

pearson_coef# te indica la correlación entre ambas variables
# Out:
# 0.8745874759642632

# %%
p_value #te indica el grado de confiabilidad del indicador
# Out:
# 9.699226565149401e-66

# %% [raw]
# Análisis de Varianza (ANOVA)
# Es un método para analizar las diferencias entre dos grupos de la misma variable

# %%
grouped_test2=df_group_one[['drive-wheels', 'length']].groupby(['drive-wheels'])
grouped_test2.head(2)
# Out:
#   drive-wheels      length
# 0          4wd  171.411111
# 1          fwd  168.780000
# 2          rwd  182.681579

# %%
df_group_one
# Out:
#   drive-wheels      length
# 0          4wd  171.411111
# 1          fwd  168.780000
# 2          rwd  182.681579

# %%
grouped_test2.get_group('4wd')['length']
# Out:
# 0    171.411111
# Name: length, dtype: float64

# %%
f_val, p_val = stats.f_oneway(grouped_test2.get_group('fwd')['length'], grouped_test2.get_group('rwd')['Length'], grouped_test2.get_group('4wd')['length'])  
 
print( "ANOVA results: F=", f_val, ", P =", p_val)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /lib/python3.10/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File /lib/python3.10/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File /lib/python3.10/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Length'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
